# %%
from sentiment_analysis.dframes import TelegramDataAnalyzer
from IPython.display import display
analyzer = TelegramDataAnalyzer()

# %%
# Get top positive messages
print("Top 15 Most Positive Messages:")
display(analyzer.get_top_messages(sentiment_type='positive', n=15,show_usernames=False))

print("\nTop 15 Most Negative Messages:")
display(analyzer.get_top_messages(sentiment_type='negative', n=15, show_usernames=False))
# Out:
#   Cell In[2], line 6
#     display(analyzer.get_top_messages(sentiment_type='negative', n=15 show_usernames=False))
#                                                                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# 1. Get statistics by date:
date_stats = analyzer.get_sentiment_stats(by='date')
display(date_stats)

#2. Get statistics by hour:
hour_stats = analyzer.get_sentiment_stats(by='hour')
display(hour_stats)

#3. Get top helpful messages:
helpful_msgs = analyzer.get_top_messages(sentiment_type='helpful', n=5,show_usernames=False)
display(helpful_msgs)

#4. Get top messages by sentiment balance:
balanced_msgs = analyzer.get_top_messages(sentiment_type='balance', n=5,show_usernames=False)
display(balanced_msgs)

#5. Get user statistics:
user_stats = analyzer.get_sentiment_stats(by='user')
display(user_stats)
# Out:
#            sentiment_positive       sentiment_negative        \
#                          mean count               mean count
# date
# 2024-10-20              0.800     1              0.100     1
# 2024-10-21              0.100     4              0.325     4
# 2024-10-22              0.375     4              0.075     4
# 2024-10-25              0.471  2696              0.287  2696
# 2024-10-26              0.459   631              0.233   631
# 2024-10-27              0.494   156              0.253   156
# 2024-10-28              0.417     6              0.200     6
#
#            sentiment_helpful       sentiment_sarcastic        \
#                         mean count                mean count
# date
# 2024-10-20             0.600     1               0.200     1
# 2024-10-21             0.225     4               0.225     4
# 2024-10-22             0.100     4               0.225     4
# 2024-10-25             0.364  2696               0.399  2696
# ...

# %%
# User Activity
print("Most Active Users and Their Sentiment Profiles:")
display(analyzer.get_most_active_users(n=10))

# %%
print("Overall Sentiment Statistics:")
display(analyzer.get_sentiment_stats(by='overall'))

# %%
print("Sentiment Trends Over Time:")
fig_trends = analyzer.plot_sentiment_trends()
fig_trends.show()

print("\nHourly Patterns:")
fig_hourly = analyzer.plot_hourly_patterns()
fig_hourly.show()
